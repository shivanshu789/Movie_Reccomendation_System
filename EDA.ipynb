# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sentence_transformers import SentenceTransformer
warnings.filterwarnings('ignore')
from huggingface_hub import hf_hub_download
import os
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv("Data\imdb_top_1000.csv")
df.head()
print(df.shape)
print(df.info())
df.isnull().sum()
df.isnull().sum()
cat_clms = df.shape
df['Meta_score']
df['Released_Year'] = pd.to_numeric(df['Released_Year'],errors='coerce')
df['Runtime'] = df['Runtime'].str.replace('min', '').astype(float)
df['Released_Year'] = pd.to_numeric(df['Released_Year'],errors='coerce')
df['Runtime'] = df['Runtime'].str.replace('min', '').astype(float)
df['Released_Year'] = pd.to_numeric(df['Released_Year'],errors='coerce')
df['Runtime'] = df['Runtime'].str.replace('min', '').astype(float) = df['Meta_score'].fillna(df['Meta_score'].mean())
df['Gross'] = df['Gross'].replace(',', '', regex=True).astype(float)
df['Gross'] = df['Gross'].fillna(df['Gross'].median())
df['Certificate'
model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')] = df['Certificate'].fillna("Unknown",inplace = True)elect_dtypes(include = 'object').columns
num_clms = df.se
embeddings = model.encode(df['Tags'].tolist(), show_progress_bar=True)
df['embeddings'] = list(embeddings)
embeddings = model.encode(df['Tags'].tolist(), show_progress_bar=True)
df['embeddings'
X = np.vstack(df['embeddings'].values)
print(X.shape)
X = np.vstack(df
sse = []
silhouette_scores = []
K = range(2, 30)

def recommend_by_cluster(movie_Series_Title, n_recs=5):
    # Find cluster of the given movie
    movie_cluster = df.loc[df['Series_Title'] == movie_Series_Title, 'cluster'].values[0]
    
df.head()

    # Get movies from the same cluster
    cluster_movies = df[df['cluster'] == movie_cluster]
    
    # Exclude the original movie and return top N
    recs = cluster_movies[cluster_movies['Series_Title'] != movie_Series_Title].sample(n=n_recs, random_state=42)
    return recs[['Series_Title', 'Tags', 'cluster']]
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)  # Sum of squared errors
    silhouette_scores.append(silhouette_score(X, kmeans.labels_))

plt.plot(K, sse, 'bx-')
plt.xlabel('k')
plt.ylabel('SSE (Inertia)')
plt.title('Elbow Method')
plt.show()

# Plot Silhouette Scores
plt.plot(K, silhouette_scores, 'bo-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method')
plt.show()['embeddings'].values)
print(X.shape)] = list(embeddings)
embeddings = model.encode(df['Tags'].tolist(), show_progress_bar=True)
df['embeddings'] = list(embeddings)lect_dtypes(include = 'number').columns
print(cat_clms,len(cat_clms))
print(num_clms,len(num_clms))
df.isnull().sum(
)
print(df.shape)
print(df.info())
